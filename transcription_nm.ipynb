# %% [markdown]
# <a href="https://colab.research.google.com/github/agalya-agalya05/speech-to-text-transcription/blob/main/transcription_nm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers torchaudio librosa noisereduce

# %%
import torch
import torchaudio
import librosa
import noisereduce as nr
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
from google.colab import files

# Upload file
uploaded = files.upload()

# Get the uploaded file name
file_name = next(iter(uploaded))

# Load and resample audio to 16kHz
signal, sr = librosa.load(file_name, sr=16000)

# Apply noise reduction
reduced_noise = nr.reduce_noise(y=signal, sr=sr)

# Load pretrained Wav2Vec2 model and processor
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

# Tokenize input
input_values = processor(reduced_noise, sampling_rate=16000, return_tensors="pt").input_values

# Perform inference
with torch.no_grad():
    logits = model(input_values).logits

# Decode prediction
predicted_ids = torch.argmax(logits, dim=-1)
transcription = processor.decode(predicted_ids[0])

# Output result
print("📝 Transcription:", transcription)
# Out:
#      <input type="file" id="files-a125a519-36a9-4699-ab74-9cebf7364639" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a125a519-36a9-4699-ab74-9cebf7364639">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
